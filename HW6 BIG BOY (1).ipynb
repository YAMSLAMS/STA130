# %% [markdown]
# 1.
#
# Simple Linear Regression is a way to explain the relationship between two variables, the predictor variable x_i and the outcome variable denoted Y_i. The predictor variable is an independent variable that is believed to influence the outcome. The outcome variable is dependent on the predictor variable and is the thing that is trying to be predicted. The slope B_1 is the amount that Y_i changes on average per one-unit increase of X. B_0 is the value of Y_i when x_i = 0. It represents the starting point of the regression line. The error term ε accounts for the difference between the observed value of
# Y_i and the value predicted by the model.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Set seed for reproducibility
np.random.seed(42)

# Define the parameters of the simple linear regression model
beta_0 = 5  # Intercept
beta_1 = 2  # Slope
sigma = 1.5  # Standard deviation of the errors (sqrt of variance)

# Generate predictor variable X (independent variable)
X = np.linspace(0, 10, 100)  # 100 points between 0 and 10

# Generate random normal errors with mean 0 and standard deviation sigma
errors = np.random.normal(0, sigma, size=X.shape)

# Calculate outcome variable Y (dependent variable) based on the regression model
Y = beta_0 + beta_1 * X + errors

# Plot the generated data and the underlying true regression line
plt.figure(figsize=(8, 6))

# Plot the observed Y values (with errors)
plt.scatter(X, Y, label='Observed Data (Y)', color='blue')

# Plot the true regression line (without errors)
Y_true = beta_0 + beta_1 * X  # True line without noise
plt.plot(X, Y_true, color='red', label=r'True Line $Y = \beta_0 + \beta_1 X$', linewidth=2)

# Add labels and title
plt.xlabel('Predictor (X)')
plt.ylabel('Outcome (Y)')
plt.title('Simple Linear Regression: True Line vs Observed Data')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
2.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Set seed for reproducibility
np.random.seed(42)

# Define parameters for the simple linear regression model
beta_0 = 5   # Intercept
beta_1 = 2   # Slope
sigma = 1.5  # Standard deviation of errors

# Generate predictor variable X
X = np.linspace(0, 10, 100)

# Generate random normal errors
errors = np.random.normal(0, sigma, size=X.shape)

# Calculate outcome variable Y
Y = beta_0 + beta_1 * X + errors

# Create a pandas DataFrame
data = pd.DataFrame({'X': X, 'Y': Y})

# Fit the Simple Linear Regression model using statsmodels
model = smf.ols(formula='Y ~ X', data=data).fit()

# Print the model summary
print(model.summary())

# Create predictions for visualization
data['Y_pred'] = model.predict(data['X'])

# Plot the observed data and the fitted regression line
plt.figure(figsize=(10, 6))
plt.scatter(data['X'], data['Y'], label='Observed Data', color='blue', alpha=0.5)
plt.plot(data['X'], data['Y_pred'], color='red', label='Fitted Line', linewidth=2)
plt.xlabel('Predictor (X)')
plt.ylabel('Outcome (Y)')
plt.title('Fitted Simple Linear Regression Model')
plt.legend()
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     1855.
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):           1.73e-65
# Time:                        01:29:51   Log-Likelihood:                -172.21
# No. Observations:                 100   AIC:                             348.4
# Df Residuals:                      98   BIC:                             353.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.7408      0.272     17.460      0.000       4.202       5.280
# ...

# %% [markdown]
# 3.
#
# The difference between the fitted and true lines lies in how we got both of them. The true line is based on the true parameter used to simulate the data. Since this line is based on the parameters B_1 and B_0, it does not account for the random error term and remains fixed always. In contrast, the fitted line is not fixed. The fitted line is derived from thhe dataset whicch includes noise thus it can only estimatte the rellationship between the X_i and Y_i variables. The more noise a dataset has, the further the fitted line will be from the true line, so as the size of a dataset increases, the noise decreases as it averages out over more points, and in turn, the fitted line gets closer to the true line.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Set seed for reproducibility
np.random.seed(42)

# Define parameters for the simple linear regression model
beta_0 = 5   # Intercept
beta_1 = 2   # Slope
sigma = 1.5  # Standard deviation of errors

# Generate predictor variable X
X = np.linspace(0, 10, 100)

# Generate random normal errors
errors = np.random.normal(0, sigma, size=X.shape)

# Calculate outcome variable Y
Y = beta_0 + beta_1 * X + errors

# Create a pandas DataFrame
data = pd.DataFrame({'X': X, 'Y': Y})

# Fit the Simple Linear Regression model using statsmodels
model = smf.ols(formula='Y ~ X', data=data).fit()

# Create predictions for visualization
data['Y_pred'] = model.predict(data['X'])

# Calculate the true regression line without noise
Y_true = beta_0 + beta_1 * X

# Plot the observed data, fitted regression line, and true regression line
plt.figure(figsize=(10, 6))
plt.scatter(data['X'], data['Y'], label='Observed Data', color='blue', alpha=0.5)
plt.plot(data['X'], data['Y_pred'], color='red', label='Fitted Line', linewidth=2)
plt.plot(data['X'], Y_true, color='green', label='True Line', linestyle='--', linewidth=2)
plt.xlabel('Predictor (X)')
plt.ylabel('Outcome (Y)')
plt.title('Fitted Simple Linear Regression Model with True Line')
plt.legend()
plt.show()

# %% [markdown]
# 4.
#
# The fitted model uses the observed data to estimate the parameters B_1 and B_0. When fitting a regression model, the estimated coefficients can be represented using fitted_model.params. The equation for this line is Y_i = B_0+B_1x_i (all variables besides x_i have triangular hats on, but I can't figure out how to put them in the equation). For each observation made with that equation, the predicted values of the outcome Y_i are the fitted values. We consider these values with fitted_model.fittedvalues. In short, the fitted_model.fitted values are calculated by substituting the predictor values into the fitted regression equation with the estimated parameters B_1 and B_0 obtained from the sample data. This is the process in which fitted_model.fittedvalues is derived.

# %%
9. 
import plotly.express as px

short_wait_limit = 100 # 64 # 66 #
short_wait = old_faithful.waiting < short_wait_limit

print(smf.ols('duration ~ waiting', data=old_faithful[short_wait]).fit().summary().tables[1])

# Create a scatter plot with a linear regression trendline
fig = px.scatter(old_faithful[short_wait], x='waiting', y='duration', 
                 title="Old Faithful Geyser Eruptions for short wait times (<"+str(short_wait_limit)+")", 
                 trendline='ols')

fig.show() # USE `fig.show(renderer="png")` FOR ALL GitHub and MarkUs SUBMISSIONS
# Out:
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.8740      0.160    -11.702      0.000      -2.189      -1.559
# waiting        0.0756      0.002     34.089      0.000       0.071       0.080
# ...

# %% [markdown]
# Null Hypothesis: There is no linear association between waiting time and eruption duration. Mathematically, this can be stated as B_1 = 0, as a slope of 0 implies that there is no change in duration with respect to a change in waiting time.
#
# Alternate Hypothesis: There is a linear association between waiting time and eruption duration. Mathematically, this can be stated as B_1 does not equal 0, as any slope that is not 0 implies some change in the duration of the waiting time changes.
#
# In this analysis, we will use a two-tailed test for the intervals of 62, 64, and 66 minutes. We will fit a regression line to each wait time and calculate the p-values. Afterwards, we will compare the p-values with predetermined alpha values (commonly set at 0.05) to determine whether to reject the null hypothesis or fail to reject it in favour of the alternative hypothesis.

# %%
import seaborn as sns
import statsmodels.formula.api as smf
import plotly.express as px

# Load dataset
old_faithful = sns.load_dataset('geyser')

# Analyze for different short wait limits
short_wait_limits = [62, 64, 66]
results = {}

for limit in short_wait_limits:
    short_wait = old_faithful.waiting < limit
    model = smf.ols('duration ~ waiting', data=old_faithful[short_wait])
    fitted_model = model.fit()
    summary = fitted_model.summary().tables[1]
    
    # Create scatter plot with regression line
    fig = px.scatter(old_faithful[short_wait], x='waiting', y='duration', 
                     title=f"Old Faithful Geyser Eruptions for short wait times (<{limit})", 
                     trendline='ols')
    fig.show(renderer="png")
    
# Create a dictionary to store p-values
p_values = {}

for limit in short_wait_limits:
    # Filter the dataset for waiting time less than the current limit
    short_wait = old_faithful[old_faithful['waiting'] < limit]
    
    # Fit the linear regression model
    model = smf.ols('duration ~ waiting', data=short_wait)
    fitted_model = model.fit()
    
    # Extract the p-value for the waiting coefficient
    p_value = fitted_model.pvalues['waiting']
    p_values[limit] = p_value

# Display the p-values
for limit, p_value in p_values.items():
    print(f'Short Wait Limit: {limit} minutes, p-value: {p_value}')
# Out:
# Short Wait Limit: 62 minutes, p-value: 0.23847876673840437
# Short Wait Limit: 64 minutes, p-value: 0.03625054688318545
# Short Wait Limit: 66 minutes, p-value: 0.0003562506426028837

# %% [markdown]
# For the wait times of 62, 64, and 68 minutes, the p-values were calculated to be 0.2384, 0.0362, and 0.0003, respectively. At a wait time of 62 minutes, the p-value shows week evidence to reject the null hypothesis. At a wait time of 64 minutes, the p-value shows moderate evidence to reject the null hypothesis. At a wait time of 66 minutes, the p-value shows strong evidence to reject the null hypothesis.
#
# So, we have one interval of time that indicates that the null hypothesis shouldn't be rejected and two that show evidence that it should. What we can extrapolate from this information is that at lower wait times, there is little to no evidence to reject the null hypothesis, but as the wait time increases, the evidence against the null hypothesis gets stronger.
#
# Thus, I conclude that at short wait times like 62 minutes, there is not sufficient evidence to reject the null hypothesis, but at wait times of 64 and 66 minutes, there is enough evidence to reject the null hypothesis.

# %%
11.

import seaborn as sns
import statsmodels.formula.api as smf
import plotly.express as px
from IPython.display import display

# Load the "Classic" Old Faithful Geyser dataset
old_faithful = sns.load_dataset('geyser')

# Define short wait and long wait limits
short_wait_limit = 68
short_wait = old_faithful['waiting'] < short_wait_limit
long_wait = old_faithful['waiting'] >= short_wait_limit

# Full model: duration ~ waiting
full_model = smf.ols('duration ~ waiting', data=old_faithful)
full_fitted_model = full_model.fit()
print("Full Dataset Model Summary:")
display(full_fitted_model.summary().tables[1])

# Short wait model: duration ~ waiting (subset with wait times < short_wait_limit)
short_model = smf.ols('duration ~ waiting', data=old_faithful[short_wait])
short_fitted_model = short_model.fit()
print("\nShort Wait Times Model Summary (waiting < 68):")
display(short_fitted_model.summary().tables[1])

# Long wait model: duration ~ waiting (subset with wait times >= short_wait_limit)
long_model = smf.ols('duration ~ waiting', data=old_faithful[long_wait])
long_fitted_model = long_model.fit()
print("\nLong Wait Times Model Summary (waiting >= 68):")
display(long_fitted_model.summary().tables[1])

# Full Model p-value for waiting
print("Full Model p-value for waiting:", f"{full_fitted_model.pvalues['waiting']:.10f}")

# Short Model p-value for waiting
print("Short Model p-value for waiting:", f"{short_fitted_model.pvalues['waiting']:.10f}")

# Long Model p-value for waiting
print("Long Model p-value for waiting:", f"{long_fitted_model.pvalues['waiting']:.10f}")


# Box plot for duration vs kind (short and long)
old_faithful['kind'] = ['short' if waiting < short_wait_limit else 'long' for waiting in old_faithful['waiting']]
fig = px.box(old_faithful, x='kind', y='duration', 
             title='Duration by Kind of Wait Time',
             category_orders={'kind': ['short', 'long']})
fig.show(renderer="png")
# Out:
# Full Dataset Model Summary:
# <class 'statsmodels.iolib.table.SimpleTable'>
# Short Wait Times Model Summary (waiting < 68):
# <class 'statsmodels.iolib.table.SimpleTable'>
# Long Wait Times Model Summary (waiting >= 68):
# <class 'statsmodels.iolib.table.SimpleTable'>
# Full Model p-value for waiting: 0.0000000000
# Short Model p-value for waiting: 0.0000090099
# Long Model p-value for waiting: 0.0000157859
# ...

# %% [markdown]
# The three model specifications highlight how the relationship between waiting time and eruption duration is not uniform across all data. The indicator variable captures the categorical nature of waiting times and makes for a clearer understanding of differences between groups.

# %% [markdown]
# Full Dataset Model (duration ~ waiting):
#
# p-value = 0.000000...
# Interpretation: The p-value of is less than 0.001, which means we reject the null hypothesis that there is no relationship between waiting time and eruption duration. Therefore, we conclude that waiting time has a significant effect on eruption duration in the full dataset.
#
# Short Wait Model (duration ~ waiting for waiting < 68):
#
# p-value = 0.0000090099
# Interpretation: The p-value of is less than 0.05, which means we reject the null hypothesis. Therefore, waiting time significantly affects eruption duration for short waits.
#
# Long Wait Model (duration ~ waiting for waiting >= 68):
#
# p-value = 0.0000157859
# Interpretation: The p-value is less than 0.05, meaning we reject the null hypothesis. Thus, waiting time significantly affects eruption duration for long waits.

# %% [markdown]
# Chatbot Summary:
#
# Model Specification Differences: We explored various model specifications to understand the relationship between waiting time and eruption duration in the Old Faithful Geyser dataset. You implemented three models:
#
# The full dataset model, analyzing duration as a function of waiting time for all observations.
# The short wait model, for waiting times under 68 minutes.
# The long wait model, for waiting times of 68 minutes or more.
# Box Plot Visualization: You added a box plot to compare eruption durations between "short" and "long" wait times, categorizing wait times as either "short" or "long" based on the 68-minute threshold.
#
# Statistical Results and Interpretation:
#
# We examined the model summaries, specifically focusing on p-values for the waiting time variable in each subset. The p-values were extremely small across the board, indicating strong evidence against the null hypothesis of "no difference between groups on average."
# This suggests that waiting time is a significant predictor of eruption duration in both short and long wait groups, though the relationship may differ between them.
# Big Picture Interpretation:
#
# Using separate models for each group (short and long wait times) reveals more nuanced differences that are not captured by a single model for the full dataset.
# The indicator variable approach with separate group regressions highlights significant structural differences between short and long wait times, affirming that eruption duration patterns differ based on the length of the wait.
#
# Link: https://chatgpt.com/c/671825bb-7088-800c-b21c-a17d9165d61a
